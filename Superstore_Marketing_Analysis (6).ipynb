# %%
df = pd.read_csv("cleaned_superstore_with_segments.csv")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram of Income
sns.histplot(df['Income'], kde=True)
plt.title("Distribution of Income")
plt.show()

# Boxplot of Recency
sns.boxplot(y=df['Recency'])
plt.title("Boxplot of Recency")
plt.show()

# %%
# Education level distribution
sns.countplot(x='Education', data=df)
plt.title("Education Distribution")
plt.xticks(rotation=45)
plt.show()

# Marital Status
sns.countplot(x='Marital_Status', data=df)
plt.title("Marital Status Distribution")
plt.show()

# %%
sns.boxplot(x='Education', y='Income', data=df)
plt.title("Income by Education Level")
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(x='Marital_Status', y='Income', data=df)
plt.title("Income by Marital Status")
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd

# Load your cleaned Superstore dataset
df = pd.read_csv("cleaned_superstore_data1.csv")  # change filename if different

# Function to create recency segments
def recency_segment(days):
    if days <= 30:
        return "Active"      # Purchased within the last month
    elif days <= 60:
        return "Warm"        # Purchased in the last 1-2 months
    else:
        return "Dormant"     # No purchase for over 2 months

# Apply the function to create a new column
df['Recency_Segment'] = df['Recency'].apply(recency_segment)

# Check how many customers are in each segment
print(df['Recency_Segment'].value_counts())

# Save to a new file
df.to_csv("cleaned_superstore_with_segments.csv", index=False)
# Out:
# Recency_Segment
# Dormant    862
# Active     724
# Warm       654
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Count of each segment
segment_counts = df['Recency_Segment'].value_counts()

# Create the bar chart
plt.figure(figsize=(6,4))
segment_counts.plot(kind='bar', color=['green', 'orange', 'red'])

# Chart details
plt.title("Customer Segments by Recency", fontsize=14)
plt.xlabel("Recency Segment", fontsize=12)
plt.ylabel("Number of Customers", fontsize=12)
plt.xticks(rotation=0)

# Show the chart
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cleaned_superstore_with_segments.csv")

# %%
print(df.shape)
df.head()
# Out:
# (2240, 26)
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  NumWebPurchases  NumCatalogPurchases  \
# 0  2014-06-16        0       189  ...                4                    4
# 1  2014-06-15        0       464  ...                7                    3
# 2  2014-05-13        0       134  ...                3                    2
# 3  2014-11-05        0        10  ...                1                    0
# 4  2014-08-04        0         6  ...                3                    1
#
#    NumStorePurchases  NumWebVisitsMonth  Response  Complain  Total_Spend  \
# 0                  6                  1         1         0         1190
# 1                  7                  5         1         0          577
# 2                  5                  2         0         0          251
# 3                  2                  7         0         0           11
# 4                  2                  7         1         0           91
#
#    Family_Size  Customer_Tenure_Days  Recency_Segment
# 0            0                  4059           Active
# 1            0                  4060           Active
# 2            1                  4093           Active
# 3            2                  3917           Active
# 4            1                  4010           Active
#
# [5 rows x 26 columns]

# %%
print(df.columns)
# Out:
# Index(['Id', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'Response', 'Complain', 'Total_Spend', 'Family_Size',
#        'Customer_Tenure_Days', 'Recency_Segment'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group and sum
sales_by_segment = df.groupby('Recency_Segment')['Total_Spend'].sum().sort_values(ascending=False)

# Plot
plt.figure(figsize=(6,4))
sns.barplot(x=sales_by_segment.index, y=sales_by_segment.values, hue=sales_by_segment.index, palette="viridis", legend=False)
plt.title("Total Spend by Recency Segment")
plt.xlabel("Recency Segment")
plt.ylabel("Total Spend")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.barplot(
    x=sales_by_education.index, 
    y=sales_by_education.values, 
    hue=sales_by_education.index, 
    palette="magma", 
    legend=False
)
plt.title("Total Spend by Education Level")
plt.xlabel("Education Level")
plt.ylabel("Total Spend")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(data=df, x='Family_Size', y='Total_Spend', hue='Recency_Segment', palette="viridis")
plt.title("Family Size vs Total Spend")
plt.xlabel("Family Size")
plt.ylabel("Total Spend")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
# Read the worksheet into a DataFrame
df = pd.read_csv("cleaned_superstore_with_segments.csv")

# Replace 'YOLO' and 'Absurd' with 'Alone' in Marital_Status column
df['Marital_Status'] = df['Marital_Status'].replace({'YOLO': 'Alone', 'Absurd': 'Alone'})

# %%
# Step 3: Save to a new Excel file
df.to_excel("cleaned_marital_status_output.xlsx", sheet_name='CleanedData', index=False)

print("Cleaned data saved to 'cleaned_marital_status_output.xlsx'")
# Out:
# Cleaned data saved to 'cleaned_marital_status_output.xlsx'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x='Marital_Status', y='Income', data=df)
plt.title("Income by Marital Status")
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
# Read the worksheet into a DataFrame
df = pd.read_csv("C:\Users\malus\Downloads\cleaned_marital_status_output.xlsx")

# Replace 'YOLO' and 'Absurd' with 'Alone' in Marital_Status column
df['Marital_Status'] = df['Marital_Status'].replace({'Yolo': 'Alone', 'Absurd': 'Alone'})
# Out:
#   Cell In[19], line 3
#     df = pd.read_csv("C:\Users\malus\Downloads\cleaned_marital_status_output.xlsx")
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd

# Read the Excel file (not CSV)
df = pd.read_excel(r"C:\Users\malus\Downloads\cleaned_marital_status_output.xlsx")

# Replace values
df['Marital_Status'] = df['Marital_Status'].replace({'Yolo': 'Alone'})

# Save to new Excel file
df.to_excel("cleaned_final_output.xlsx", index=False)

print("Data cleaned and saved to 'cleaned_final_output1.xlsx'")
# Out:
# Data cleaned and saved to 'cleaned_final_output1.xlsx'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x='Marital_Status', y='Income', data=df)
plt.title("Income by Marital Status")
plt.xticks(rotation=45)
plt.show()
